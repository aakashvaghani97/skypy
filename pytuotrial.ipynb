# %%
a = "Hello Ayushi"  #variable id the container which contains the location of data
b=1
c = 34.5
d = " I am Akash"
e ="50"
f ="60"
print (b)
print (type(a))
print (type(b))
print (type(c))
print (a+d)
print (int(e)+int(f))
print (100*str(int(e)+int(f)))#type casting #float int doble
# Out:
# 1
# <class 'str'>
# <class 'int'>
# <class 'float'>
# Hello Ayushi I am Akash
# 110
# 

# %%
print ("i am the sky","i am Akash")
# Out:
# i am the sky i am Akash
